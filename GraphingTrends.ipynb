# %% [markdown]
# ## Udacity - Project 1 - Exploring Weather Trends (Toronto vs. Global average Temperatures)

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; Importing Libraries

# %%
#importing necessary packages needed to execute graphing and 
#calculating moving average means

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; Extracting CSV files

# %%
#using Pandas to read the CSV file that was exported from SQL 
df = pd.read_csv("results.csv")
df.head() #displays the first 5 values of the table
# Out:
#    year  global_avg_temp  city_avg_temp
# 0  1750             8.72           6.29
# 1  1751             7.98           6.84
# 2  1752             5.78          -1.10
# 3  1753             8.39           5.76
# 4  1754             8.47           5.94

# %%
df.tail()
# Out:
#      year  global_avg_temp  city_avg_temp
# 259  2009             9.51           6.28
# 260  2010             9.70           7.77
# 261  2011             9.52           7.30
# 262  2012             9.51           8.66
# 263  2013             9.61           8.46

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; Calculating Moving Averages for Global and City temperatures

# %%
#The following code is used to deduce rolling means; needed to smoothen the lines for graphing
global_avg = df['global_avg_temp'].rolling(10).mean()
city_avg = df['city_avg_temp'].rolling(10).mean()

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; Plotting Year vs. Global and City average temperatures using Matplotlib Library

# %%
#using plot function to assign X and Y variables
plt.plot(df['year'], global_avg, label = 'Global', color='b');
plt.plot(df['year'], city_avg, label = 'Toronto', color='orange');

#used xticks here to create intervals of 30 years at a time
plt.xticks(np.arange(min(df['year']), max(df['year'])+15, 30.0))  

#Legend to differentiate colours on graph and labels to easily identify x and y labels
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Comparison of Global and Toronto average temperature")
plt.show()

# %%
#using plot function to assign X and Y variables
plt.plot(df['year'], global_avg, label = 'Global', color='b');


#used xticks here to create intervals of 30 years at a time
plt.xticks(np.arange(min(df['year']), max(df['year'])+15, 30.0))  

#Legend to differentiate colours on graph and labels to easily identify x and y labels
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("Global average temperature")
plt.show()

# %%
#using plot function to assign X and Y variables
plt.plot(df['year'], city_avg, label = 'Toronto', color='orange');


#used xticks here to create intervals of 30 years at a time
plt.xticks(np.arange(min(df['year']), max(df['year'])+15, 30.0))  

#Legend to differentiate colours on graph and labels to easily identify x and y labels
plt.legend()
plt.xlabel("Years")
plt.ylabel("Temperature (°C)") 
plt.title("City average temperature")
plt.show()
